# %% [markdown]
# # Data Summary & Clean Up

# %%
import pandas as pd
from pathlib import Path

file = Path('Resources/cannabis_market_data.csv')
df = pd.read_csv(file,encoding='utf-8')
df.head()
# Out:
#    _id year_-_month                              product_type  \
# 0    1     2019-10   cannabis extracts / extraits de cannabis
# 1    2     2019-11   cannabis extracts / extraits de cannabis
# 2    3     2019-12   cannabis extracts / extraits de cannabis
# 3    4     2020-01   cannabis extracts / extraits de cannabis
# 4    5     2020-02   cannabis extracts / extraits de cannabis
#
#   unpackaged_production_units unpackaged_inventory_units  \
# 0                   n/a / n/d                  n/a / n/d
# 1                   n/a / n/d                  n/a / n/d
# 2                   n/a / n/d                  n/a / n/d
# 3                   n/a / n/d                  n/a / n/d
# 4                   n/a / n/d                  n/a / n/d
#
#   packaged_production_units  \
# 0                    732388
# 1                    430658
# 2                   1245160
# 3                    973120
# 4                   1127995
#
#   packaged_inventory_units_-_federal_licence_holders  \
# 0                                            5630075
# 1                                            5595722
# 2                                            5882326
# 3                                            6009120
# 4                                            5877090
#
#   packaged_inventory_units_-_provincial_distributors_and_retailer  \
# 0                                            1820111
# 1                                            1676016
# 2                                            1776396
# 3                                            1803543
# 4                                            2023192
#
#   sales_units_-_medical sales_units_-_non-medical  \
# 0                167357                    320201
# 1                182506                    328908
# 2                195560                    400707
# 3                201236                    527978
# 4                187945                    599407
#
#   unpackaged_production_kilograms unpackaged_inventory_kilograms  \
# 0                       n/a / n/d                      n/a / n/d
# 1                       n/a / n/d                      n/a / n/d
# 2                       n/a / n/d                      n/a / n/d
# 3                       n/a / n/d                      n/a / n/d
# 4                       n/a / n/d                      n/a / n/d
#
#   packaged_production_kilograms  \
# 0                     n/a / n/d
# 1                     n/a / n/d
# 2                     n/a / n/d
# 3                     n/a / n/d
# 4                     n/a / n/d
#
#   packaged_inventory_kilograms_-_federal_licence_holders  \
# 0                                          n/a / n/d
# 1                                          n/a / n/d
# 2                                          n/a / n/d
# 3                                          n/a / n/d
# 4                                          n/a / n/d
#
#   packaged_inventory_kilograms_-_provincial_distributors_and_reta  \
# 0                                          n/a / n/d
# 1                                          n/a / n/d
# 2                                          n/a / n/d
# 3                                          n/a / n/d
# 4                                          n/a / n/d
#
#   sales_kilograms_-_medical sales_kilograms_-_non-medical
# 0                 n/a / n/d                     n/a / n/d
# 1                 n/a / n/d                     n/a / n/d
# 2                 n/a / n/d                     n/a / n/d
# 3                 n/a / n/d                     n/a / n/d
# 4                 n/a / n/d                     n/a / n/d

# %%
#Delete Columns 
columns_to_delete = ['unpackaged_production_units', 'unpackaged_inventory_units',
                     'unpackaged_production_kilograms','unpackaged_inventory_kilograms',
                    'packaged_production_kilograms','packaged_inventory_kilograms_-_federal_licence_holders',
                     'packaged_inventory_kilograms_-_provincial_distributors_and_reta', 
                     'sales_kilograms_-_medical', 'sales_kilograms_-_non-medical']

second_df = df.drop(columns=columns_to_delete)

second_df.head()
# Out:
#    _id year_-_month                              product_type  \
# 0    1     2019-10   cannabis extracts / extraits de cannabis
# 1    2     2019-11   cannabis extracts / extraits de cannabis
# 2    3     2019-12   cannabis extracts / extraits de cannabis
# 3    4     2020-01   cannabis extracts / extraits de cannabis
# 4    5     2020-02   cannabis extracts / extraits de cannabis
#
#   packaged_production_units  \
# 0                    732388
# 1                    430658
# 2                   1245160
# 3                    973120
# 4                   1127995
#
#   packaged_inventory_units_-_federal_licence_holders  \
# 0                                            5630075
# 1                                            5595722
# 2                                            5882326
# 3                                            6009120
# 4                                            5877090
#
#   packaged_inventory_units_-_provincial_distributors_and_retailer  \
# 0                                            1820111
# 1                                            1676016
# 2                                            1776396
# 3                                            1803543
# 4                                            2023192
#
#   sales_units_-_medical sales_units_-_non-medical
# 0                167357                    320201
# 1                182506                    328908
# 2                195560                    400707
# 3                201236                    527978
# 4                187945                    599407

# %%
# Convert 'year_-_month' column to datetime format with specified format
second_df['year_-_month'] = second_df['year_-_month'].str.strip()
default_date = '1900-01'
second_df['year_-_month'].fillna(default_date, inplace=True)
empty_strings = second_df[second_df['year_-_month'] == '']

second_df['year_-_month'] = pd.to_datetime(second_df['year_-_month'], format='%Y-%m')

# Display the updated DataFrame
second_df
# Out:
#      _id year_-_month                                       product_type  \
# 0      1   2019-10-01           cannabis extracts / extraits de cannabis
# 1      2   2019-11-01           cannabis extracts / extraits de cannabis
# 2      3   2019-12-01           cannabis extracts / extraits de cannabis
# 3      4   2020-01-01           cannabis extracts / extraits de cannabis
# 4      5   2020-02-01           cannabis extracts / extraits de cannabis
# ..   ...          ...                                                ...
# 322  323   2023-02-01  whole cannabis plants / plantes de cannabis en...
# 323  324   2023-03-01  whole cannabis plants / plantes de cannabis en...
# 324  325   2023-04-01  whole cannabis plants / plantes de cannabis en...
# 325  326   2023-05-01  whole cannabis plants / plantes de cannabis en...
# 326  327   2023-06-01  whole cannabis plants / plantes de cannabis en...
#
#     packaged_production_units  \
# 0                      732388
# 1                      430658
# 2                     1245160
# 3                      973120
# 4                     1127995
# ..                        ...
# 322                 n/a / n/d
# 323                 n/a / n/d
# 324                 n/a / n/d
# 325                 n/a / n/d
# 326                 n/a / n/d
#
#     packaged_inventory_units_-_federal_licence_holders  \
# 0                                              5630075
# 1                                              5595722
# 2                                              5882326
# 3                                              6009120
# 4                                              5877090
# ..                                                 ...
# 322                                          n/a / n/d
# 323                                          n/a / n/d
# 324                                          n/a / n/d
# 325                                          n/a / n/d
# 326                                          n/a / n/d
#
#     packaged_inventory_units_-_provincial_distributors_and_retailer  \
# 0                                              1820111
# 1                                              1676016
# 2                                              1776396
# 3                                              1803543
# 4                                              2023192
# ..                                                 ...
# 322                                          n/a / n/d
# 323                                          n/a / n/d
# 324                                          n/a / n/d
# 325                                          n/a / n/d
# 326                                          n/a / n/d
#
#     sales_units_-_medical sales_units_-_non-medical
# 0                  167357                    320201
# 1                  182506                    328908
# 2                  195560                    400707
# 3                  201236                    527978
# 4                  187945                    599407
# ..                    ...                       ...
# 322             n/a / n/d                 n/a / n/d
# 323             n/a / n/d                 n/a / n/d
# 324             n/a / n/d                 n/a / n/d
# 325             n/a / n/d                 n/a / n/d
# 326             n/a / n/d                 n/a / n/d
#
# [327 rows x 8 columns]

# %%
#Remove special characters from my set
pattern = r'[^\w\s]'
second_df['product_type'] = df['product_type'].replace(pattern, '', regex=True)
second_df['packaged_production_units'] = df['packaged_production_units'].replace(pattern, '', regex=True)
second_df['packaged_inventory_units_-_federal_licence_holders'] = df['packaged_inventory_units_-_federal_licence_holders'].replace(pattern, '', regex=True)
second_df['packaged_inventory_units_-_provincial_distributors_and_retailer'] = df['packaged_inventory_units_-_provincial_distributors_and_retailer'].replace(pattern, '', regex=True)
second_df['sales_units_-_medical'] = df['sales_units_-_medical'].replace(pattern, '', regex=True)



second_df
# Out:
#      _id year_-_month                                       product_type  \
# 0      1   2019-10-01            cannabis extracts  extraits de cannabis
# 1      2   2019-11-01            cannabis extracts  extraits de cannabis
# 2      3   2019-12-01            cannabis extracts  extraits de cannabis
# 3      4   2020-01-01            cannabis extracts  extraits de cannabis
# 4      5   2020-02-01            cannabis extracts  extraits de cannabis
# ..   ...          ...                                                ...
# 322  323   2023-02-01  whole cannabis plants  plantes de cannabis ent...
# 323  324   2023-03-01  whole cannabis plants  plantes de cannabis ent...
# 324  325   2023-04-01  whole cannabis plants  plantes de cannabis ent...
# 325  326   2023-05-01  whole cannabis plants  plantes de cannabis ent...
# 326  327   2023-06-01  whole cannabis plants  plantes de cannabis ent...
#
#     packaged_production_units  \
# 0                      732388
# 1                      430658
# 2                     1245160
# 3                      973120
# 4                     1127995
# ..                        ...
# 322                    na  nd
# 323                    na  nd
# 324                    na  nd
# 325                    na  nd
# 326                    na  nd
#
#     packaged_inventory_units_-_federal_licence_holders  \
# 0                                              5630075
# 1                                              5595722
# 2                                              5882326
# 3                                              6009120
# 4                                              5877090
# ..                                                 ...
# 322                                             na  nd
# 323                                             na  nd
# 324                                             na  nd
# 325                                             na  nd
# 326                                             na  nd
#
#     packaged_inventory_units_-_provincial_distributors_and_retailer  \
# 0                                              1820111
# 1                                              1676016
# 2                                              1776396
# 3                                              1803543
# 4                                              2023192
# ..                                                 ...
# 322                                             na  nd
# 323                                             na  nd
# 324                                             na  nd
# 325                                             na  nd
# 326                                             na  nd
#
#     sales_units_-_medical sales_units_-_non-medical
# 0                  167357                    320201
# 1                  182506                    328908
# 2                  195560                    400707
# 3                  201236                    527978
# 4                  187945                    599407
# ..                    ...                       ...
# 322                na  nd                 n/a / n/d
# 323                na  nd                 n/a / n/d
# 324                na  nd                 n/a / n/d
# 325                na  nd                 n/a / n/d
# 326                na  nd                 n/a / n/d
#
# [327 rows x 8 columns]

# %%
#Name my Columns
second_df.columns.tolist()
# Out:
# ['_id',
#  'year_-_month',
#  'product_type',
#  'packaged_production_units',
#  'packaged_inventory_units_-_federal_licence_holders',
#  'packaged_inventory_units_-_provincial_distributors_and_retailer',
#  'sales_units_-_medical',
#  'sales_units_-_non-medical']

# %%
second_df = second_df.rename(columns={'year_-_month': "Year/Month", 'product_type': "Product Type", 
                                     'packaged_production_units': "Total Packaged Units", 
                                     'packaged_inventory_units_-_federal_licence_holders': "Federal Inventory",
                                     'packaged_inventory_units_-_provincial_distributors_and_retailer': "Retail Inventory",
                                     'sales_units_-_medical': "Medical Sales(units)", 'sales_units_-_non-medical': "Retail Sales(units)"})




second_df
# Out:
#      _id Year/Month                                       Product Type  \
# 0      1 2019-10-01            cannabis extracts  extraits de cannabis
# 1      2 2019-11-01            cannabis extracts  extraits de cannabis
# 2      3 2019-12-01            cannabis extracts  extraits de cannabis
# 3      4 2020-01-01            cannabis extracts  extraits de cannabis
# 4      5 2020-02-01            cannabis extracts  extraits de cannabis
# ..   ...        ...                                                ...
# 322  323 2023-02-01  whole cannabis plants  plantes de cannabis ent...
# 323  324 2023-03-01  whole cannabis plants  plantes de cannabis ent...
# 324  325 2023-04-01  whole cannabis plants  plantes de cannabis ent...
# 325  326 2023-05-01  whole cannabis plants  plantes de cannabis ent...
# 326  327 2023-06-01  whole cannabis plants  plantes de cannabis ent...
#
#     Total Packaged Units Federal Inventory Retail Inventory  \
# 0                 732388           5630075          1820111
# 1                 430658           5595722          1676016
# 2                1245160           5882326          1776396
# 3                 973120           6009120          1803543
# 4                1127995           5877090          2023192
# ..                   ...               ...              ...
# 322               na  nd            na  nd           na  nd
# 323               na  nd            na  nd           na  nd
# 324               na  nd            na  nd           na  nd
# 325               na  nd            na  nd           na  nd
# 326               na  nd            na  nd           na  nd
#
#     Medical Sales(units) Retail Sales(units)
# 0                 167357              320201
# 1                 182506              328908
# 2                 195560              400707
# 3                 201236              527978
# 4                 187945              599407
# ..                   ...                 ...
# 322               na  nd           n/a / n/d
# 323               na  nd           n/a / n/d
# 324               na  nd           n/a / n/d
# 325               na  nd           n/a / n/d
# 326               na  nd           n/a / n/d
#
# [327 rows x 8 columns]

# %%
#Check for missing values in remaining Data 
second_df.isnull().sum()
# Out:
# _id                     0
# Year/Month              0
# Product Type            0
# Total Packaged Units    0
# Federal Inventory       0
# Retail Inventory        0
# Medical Sales(units)    0
# Retail Sales(units)     0
# dtype: int64

# %%
#Check the Data Types for my columns 
second_df.dtypes
# Out:
# _id                              int64
# Year/Month              datetime64[ns]
# Product Type                    object
# Total Packaged Units            object
# Federal Inventory               object
# Retail Inventory                object
# Medical Sales(units)            object
# Retail Sales(units)             object
# dtype: object

# %%
#Convert the Data Types to numeric for plotting graphs and check Types again
numeric_columns = ['Total Packaged Units', 'Federal Inventory', 'Retail Inventory', 'Medical Sales(units)', 'Retail Sales(units)']
second_df[numeric_columns] = second_df[numeric_columns].apply(pd.to_numeric, errors='coerce')

second_df.dtypes
# Out:
# _id                              int64
# Year/Month              datetime64[ns]
# Product Type                    object
# Total Packaged Units           float64
# Federal Inventory              float64
# Retail Inventory               float64
# Medical Sales(units)           float64
# Retail Sales(units)            float64
# dtype: object

# %%
second_df.set_index("Year/Month", inplace=True)
second_df
# Out:
#             _id                                       Product Type  \
# Year/Month
# 2019-10-01    1            cannabis extracts  extraits de cannabis
# 2019-11-01    2            cannabis extracts  extraits de cannabis
# 2019-12-01    3            cannabis extracts  extraits de cannabis
# 2020-01-01    4            cannabis extracts  extraits de cannabis
# 2020-02-01    5            cannabis extracts  extraits de cannabis
# ...         ...                                                ...
# 2023-02-01  323  whole cannabis plants  plantes de cannabis ent...
# 2023-03-01  324  whole cannabis plants  plantes de cannabis ent...
# 2023-04-01  325  whole cannabis plants  plantes de cannabis ent...
# 2023-05-01  326  whole cannabis plants  plantes de cannabis ent...
# 2023-06-01  327  whole cannabis plants  plantes de cannabis ent...
#
#             Total Packaged Units  Federal Inventory  Retail Inventory  \
# Year/Month
# 2019-10-01              732388.0          5630075.0         1820111.0
# 2019-11-01              430658.0          5595722.0         1676016.0
# 2019-12-01             1245160.0          5882326.0         1776396.0
# 2020-01-01              973120.0          6009120.0         1803543.0
# 2020-02-01             1127995.0          5877090.0         2023192.0
# ...                          ...                ...               ...
# 2023-02-01                   NaN                NaN               NaN
# 2023-03-01                   NaN                NaN               NaN
# 2023-04-01                   NaN                NaN               NaN
# 2023-05-01                   NaN                NaN               NaN
# 2023-06-01                   NaN                NaN               NaN
#
#             Medical Sales(units)  Retail Sales(units)
# Year/Month
# 2019-10-01              167357.0             320201.0
# 2019-11-01              182506.0             328908.0
# 2019-12-01              195560.0             400707.0
# 2020-01-01              201236.0             527978.0
# 2020-02-01              187945.0             599407.0
# ...                          ...                  ...
# 2023-02-01                   NaN                  NaN
# 2023-03-01                   NaN                  NaN
# 2023-04-01                   NaN                  NaN
# 2023-05-01                   NaN                  NaN
# 2023-06-01                   NaN                  NaN
#
# [327 rows x 7 columns]

# %% [markdown]
# # Data Analysis

# %%
second_df.columns.tolist()
# Out:
# ['_id',
#  'Product Type',
#  'Total Packaged Units',
#  'Federal Inventory',
#  'Retail Inventory',
#  'Medical Sales(units)',
#  'Retail Sales(units)']

# %%
#Calculate the Mean of Retail Sales and Medical Sales to get the average sale/month (to show growth in retail sales)
mean_retail_sales = second_df['Retail Sales(units)'].mean()
mean_medical_sales = second_df['Medical Sales(units)'].mean()
difference_in_sales = mean_retail_sales - mean_medical_sales
print("Mean Retail Sales(units):", mean_retail_sales)
print("Mean Medical Sales(units):", mean_medical_sales)
print("The difference between Average Retail and Medical sales per month (in units):", difference_in_sales)
# Out:
# Mean Retail Sales(units): 1856075.639423077
# Mean Medical Sales(units): 104952.21851851852
# The difference between Average Retail and Medical sales per month (in units): 1751123.4209045584

# %%
#Looking at the sales per Year
df.index = pd.to_datetime(df.index)
second_df['Year'] = df.index.year


by_year_sales = second_df.groupby('Year').agg({'Retail Sales(units)': 'mean', 'Medical Sales(units)': 'mean'})
pd.options.display.float_format = '{:.2f}'.format

by_year_sales
# Out:
#       Retail Sales(units)  Medical Sales(units)
# Year
# 1970           1856075.64             104952.22
